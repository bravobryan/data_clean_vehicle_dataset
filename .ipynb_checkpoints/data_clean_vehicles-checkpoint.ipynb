# %% [markdown]
# # Data Cleaning and Exploratory Data Analysis Project
# A project to perform data cleaning tasks, such as detection, treatment, transformation, and data visualization.
#
# The "Vehicle Dataset 2024" dataset was found through Kaggle.com and is available under the ODC Attribution License. https://www.kaggle.com/datasets/kanchana1990/vehicle-dataset-2024
#
# ## Dataset Variables
# - `name`: The full name of the vehicle, including make, model, and trim.
# - `description`: A brief vehicle description, often including key features and selling points.
# - `make`: The vehicle manufacturer (Ford, Toyota, BMW).
# - `model`: The model name of the vehicle.
# - `type`: The type of the vehicle, which is "New" for all entries in this dataset.
# - `year`: The year the vehicle was manufactured.
# - `price`: The price of the vehicle in USD.
# - `engine`: Details about the engine, including type and specifications.
# - `cylinders`: The number of cylinders in the vehicle's engine.
# - `fuel`: The type of fuel the vehicle uses (Gasoline, Diesel, Electric).
# - `mileage`: The vehicle's mileage, typically in miles.
# - `transmission`: The transmission type (Automatic, Manual).
# - `trim`: The trim level of the vehicle, indicating different feature sets or packages.
# - `body`: The vehicle's body style (SUV, Sedan, Pickup Truck).
# - `doors`: The number of doors on the vehicle.
# - `exterior_color`: The exterior color of the vehicle.
# - `interior_color`: The interior color of the vehicle.
# - `drivetrain`: The vehicle's drivetrain (All-wheel Drive, Front-wheel Drive)
#
# # Import Libraries and Dataset

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import missingno as msno
import statistics
warnings.filterwarnings('ignore')

sns.set_theme(style='darkgrid', palette='Dark2')

# %%
##-- Import Dataset --##
vehicle_df = pd.read_csv('dataset/vehicles_dataset.csv')

vehicle_df.info()
vehicle_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1002 non-null   object
#  1   description     946 non-null    object
#  2   make            1002 non-null   object
#  3   model           1002 non-null   object
#  4   type            1002 non-null   object
#  5   year            1002 non-null   int64
#  6   price           979 non-null    float64
#  7   engine          1000 non-null   object
#  8   cylinders       897 non-null    float64
#  9   fuel            995 non-null    object
#  10  mileage         968 non-null    float64
#  11  transmission    1000 non-null   object
#  12  trim            1001 non-null   object
#  13  body            999 non-null    object
#  14  doors           995 non-null    float64
#  15  exterior_color  997 non-null    object
#  16  interior_color  964 non-null    object
#  17  drivetrain      1002 non-null   object
# dtypes: float64(4), int64(1), object(13)
# memory usage: 141.0+ KB
#                               name  \
# 0     2024 Jeep Wagoneer Series II
# 1  2024 Jeep Grand Cherokee Laredo
# 2         2024 GMC Yukon XL Denali
# 3       2023 Dodge Durango Pursuit
# 4            2024 RAM 3500 Laramie
#
#                                          description   make           model  \
# 0  \n      \n        Heated Leather Seats, Nav Sy...   Jeep        Wagoneer
# 1  Al West is committed to offering every custome...   Jeep  Grand Cherokee
# 2                                                NaN    GMC        Yukon XL
# 3  White Knuckle Clearcoat 2023 Dodge Durango Pur...  Dodge         Durango
# 4  \n      \n        2024 Ram 3500 Laramie Billet...    RAM            3500
#
#   type  year    price                                             engine  \
# 0  New  2024  74600.0                            24V GDI DOHC Twin Turbo
# 1  New  2024  50170.0                                                OHV
# 2  New  2024  96410.0  6.2L V-8 gasoline direct injection, variable v...
# 3  New  2023  46835.0                                       16V MPFI OHV
# 4  New  2024  81663.0                           24V DDI OHV Turbo Diesel
#
#    cylinders      fuel  mileage       transmission       trim          body  \
# 0        6.0  Gasoline     10.0  8-Speed Automatic  Series II           SUV
# 1        6.0  Gasoline      1.0  8-Speed Automatic     Laredo           SUV
# 2        8.0  Gasoline      0.0          Automatic     Denali           SUV
# 3        8.0  Gasoline     32.0  8-Speed Automatic    Pursuit           SUV
# 4        6.0    Diesel     10.0  6-Speed Automatic    Laramie  Pickup Truck
#
#    doors           exterior_color    interior_color        drivetrain
# 0    4.0                    White      Global Black  Four-wheel Drive
# 1    4.0                 Metallic      Global Black  Four-wheel Drive
# 2    4.0             Summit White  Teak/Light Shale  Four-wheel Drive
# 3    4.0  White Knuckle Clearcoat             Black   All-wheel Drive
# 4    4.0                   Silver             Black  Four-wheel Drive

# %% [markdown]
# # Data Cleaning
# ## Detection of Duplicate Rows

# %%
# Detection of duplicates.
duplicates = vehicle_df.duplicated()  
dupl_counts = duplicates.value_counts() 

print(f'Total duplicate rows: {duplicates.sum()} \n')
print(f'True vs. False counts: \n {dupl_counts}')
# Out:
# Total duplicate rows: 24
#
# True vs. False counts:
#  False    978
# True      24
# Name: count, dtype: int64

# %% [markdown]
# ### Inspection of Duplicate Rows
# 24 Rows were found to be duplicate.

# %%
##-- Subset duplicate rows
vehicle_df[vehicle_df.duplicated(keep=False)].sort_values('description').head()
# Out:
#                                    name  \
# 304        2024 Honda CR-V Hybrid Sport
# 637        2024 Honda CR-V Hybrid Sport
# 398  2024 Mazda CX-90 PHEV Premium Plus
# 206  2024 Mazda CX-90 PHEV Premium Plus
# 158              2023 Dodge Charger SXT
#
#                                            description   make        model  \
# 304  \n      \n        !!! CALL US AT (812) 477-620...  Honda  CR-V Hybrid
# 637  \n      \n        !!! CALL US AT (812) 477-620...  Honda  CR-V Hybrid
# 398  \n      \n        At Walser, youll get an exce...  Mazda   CX-90 PHEV
# 206  \n      \n        At Walser, youll get an exce...  Mazda   CX-90 PHEV
# 158  \n      \n        F8 Green exterior and Black ...  Dodge      Charger
#
#     type  year    price                 engine  cylinders              fuel  \
# 304  New  2024  36900.0    16V GDI DOHC Hybrid        4.0            Hybrid
# 637  New  2024  36900.0    16V GDI DOHC Hybrid        4.0            Hybrid
# 398  New  2024  58399.0  DOHC 16V LEV3-SULEV30        4.0  PHEV Hybrid Fuel
# 206  New  2024  58399.0  DOHC 16V LEV3-SULEV30        4.0  PHEV Hybrid Fuel
# 158  New  2023  37490.0          24V MPFI DOHC        6.0          Gasoline
#
#      mileage       transmission          trim   body  doors  \
# 304      1.0      Automatic CVT         Sport    SUV    4.0
# 637      1.0      Automatic CVT         Sport    SUV    4.0
# 398      4.0          Automatic  Premium Plus    SUV    4.0
# 206      4.0          Automatic  Premium Plus    SUV    4.0
# 158     20.0  8-Speed Automatic           SXT  Sedan    4.0
#
#             exterior_color interior_color        drivetrain
# 304  Lunar Silver Metallic          Black   All-wheel Drive
# 637  Lunar Silver Metallic          Black   All-wheel Drive
# 398  Rhodium White Premium          Black   All-wheel Drive
# 206  Rhodium White Premium          Black   All-wheel Drive
# 158                  Green          Black  Rear-wheel Drive

# %% [markdown]
# ## Treatment of Duplicate Rows
# The `description` variable will be extracted into a separate dataset for later analysis since this variable can be useful for Natural Language processing. Removing the `description` variable may create additional duplicate rows. All duplicate rows will be dropped on the continued dataset.

# %%
vehicle_only_df = vehicle_df.drop('description', axis=1)

# Detection of duplicates cleaned dataframe
duplicates = vehicle_only_df.duplicated()  
dupl_counts = duplicates.value_counts() 

print(f'Total duplicate rows Before Dropping: {duplicates.sum()} \n')
print(f'True vs. False counts: \n {dupl_counts} \n')

vehicle_only_df.drop_duplicates(inplace=True)

duplicates = vehicle_only_df.duplicated()  
dupl_counts = duplicates.value_counts() 

print(f'Total duplicate rows After Dropping: {duplicates.sum()} \n')
print(f'True vs. False counts: \n {dupl_counts}')
# Out:
# Total duplicate rows Before Dropping: 31
#
# True vs. False counts:
#  False    971
# True      31
# Name: count, dtype: int64
#
# Total duplicate rows After Dropping: 0
#
# True vs. False counts:
#  False    971
# Name: count, dtype: int64

# %% [markdown]
# ## Detection of Missing Values

# %%
##-- Detection of missing values --##
print(f'Total count of missing values: {vehicle_only_df.isna().sum().sum()}')
print(vehicle_only_df.isna().sum())  # Generates the count of missing values per column.

##-- Visualization of missing values --##
print(f'Data Sparsity: {vehicle_only_df.isna().sum().sum() / (vehicle_only_df.shape[0] * vehicle_only_df.shape[1])}')
msno.matrix(vehicle_only_df, labels=True)
plt.title('Missingness in the "vehicle_only_df" DataFrame')
plt.show()
# Out:
# Total count of missing values: 223
# name                0
# make                0
# model               0
# type                0
# year                0
# price              23
# engine              2
# cylinders         103
# fuel                7
# mileage            32
# transmission        2
# trim                1
# body                3
# doors               7
# exterior_color      5
# interior_color     38
# drivetrain          0
# dtype: int64
# Data Sparsity: 0.013509420245956262

# %% [markdown]
# ## Treatment of Missing Values
# **Variables with Missing Values**:
# - `price`: 23 missing,
# - `engine`: 2 missing,
# - `cylinders`: 103 missing,
# - `fuel`: 7 missing,
# - `mileage`: 32 missing,
# - `transmission`: 2 missing,
# - `trim`: 1 missing,
# - `body`: 3 missing,
# - `doors`: 7 missing,
# - `exterior_color`: 5 missing, and
# - `interior_color`: 38 missing.
#
# 283 total missing values present in the dataset with a **Data Sparsity** of < 2%.
#
# ### `price` Variable - Missing Values
# - 23 missing values

# %%
##-- Visual inspection of price distribution between different makes.
sns.catplot(
    x='make', y='price',
    data=vehicle_only_df.dropna(), kind='box',
    aspect=5/2
)
plt.xticks(rotation=45)
plt.grid(True)
plt.title('Price Distribution Between Different Vehicle Make', y=1.03)
plt.show()

# %% [markdown]
# A glance at the distribution between different vehicle manufacturers reveals their price differences. Additionally, the distributions between different vehicle manufacturers are skewed, meaning that the best way to fill in missing values is to perform a median imputation based on `make` and `model`.
#
# #### Impute missing values in the `price` column considering vehicle `make` and `model`.
# 1. Aggregate median values between make and model.
# 2. Create a loop to impute missing values for rows where make and model match.

# %%
#-- Find median based on make and model
median_vals = vehicle_only_df.groupby(['make', 'model'])['price'].median().reset_index()
print(median_vals[median_vals['price'].isna()])  # Check for missing values in the df
median_vals
# Out:
#               make    model  price
# 9              BMW      530    NaN
# 118  Mercedes-Benz  GLE 350    NaN
#            make                         model    price
# 0         Acura                           MDX  56155.0
# 1         Acura                           ZDX  69850.0
# 2          Audi                            A3  39375.0
# 3          Audi                  A5 Sportback  56105.0
# 4          Audi                          Q5 e  73190.0
# ..          ...                           ...      ...
# 148  Volkswagen                         Jetta  25923.0
# 149  Volkswagen                          Taos  29226.0
# 150       Volvo    C40 Recharge Pure Electric  62240.0
# 151       Volvo   S60 Recharge Plug-In Hybrid  57545.0
# 152       Volvo  XC90 Recharge Plug-In Hybrid  75595.0
#
# [153 rows x 3 columns]

# %% [markdown]
# The dataset's `BMW 530` and the `Mercedes-Benz GLE 350` came up with missing values after aggregating the median value.
# Values related to these vehicles will be dropped from the dataset, and all other missing values will be imputed using the `median_vals` DataFrame.

# %%
##-- Drop defined rows, then impute median values --##
dropping_rows = vehicle_only_df[vehicle_only_df['model'].isin(['530', 'GLE 350'])]
vehicle_only_df.drop(dropping_rows.index, axis=0, inplace=True)


# Create a loop that imputes null values based on the vehicle model.
values = []
for i in range(vehicle_only_df.shape[0]):
    if pd.isnull(vehicle_only_df.iloc[i,5]):  # Checks if row is null on price variable
        m = vehicle_only_df.iloc[i,2]  # Extracts model name
        values.append(float(median_vals[median_vals['model']==m]['price']))  # append median value
    else:
        values.append(vehicle_only_df.iloc[i,5])  # append original price value

# Inspect missing values before and after imputation.
vehicle_only_df['price_check'] = values
print(vehicle_only_df[['price', 'price_check']].isna().sum())
# Out:
# price          21
# price_check     0
# dtype: int64

# %%
##-- replace 'price' with 'price_check' --##
vehicle_only_df['price'] = vehicle_only_df['price_check']
vehicle_only_df.drop('price_check', axis=1, inplace=True)
print(f"Total Missing values for 'price' variable: {vehicle_only_df['price'].isna().sum()}")
vehicle_only_df.head()
# Out:
# Total Missing values for 'price' variable: 0
#                               name   make           model type  year    price  \
# 0     2024 Jeep Wagoneer Series II   Jeep        Wagoneer  New  2024  74600.0
# 1  2024 Jeep Grand Cherokee Laredo   Jeep  Grand Cherokee  New  2024  50170.0
# 2         2024 GMC Yukon XL Denali    GMC        Yukon XL  New  2024  96410.0
# 3       2023 Dodge Durango Pursuit  Dodge         Durango  New  2023  46835.0
# 4            2024 RAM 3500 Laramie    RAM            3500  New  2024  81663.0
#
#                                               engine  cylinders      fuel  \
# 0                            24V GDI DOHC Twin Turbo        6.0  Gasoline
# 1                                                OHV        6.0  Gasoline
# 2  6.2L V-8 gasoline direct injection, variable v...        8.0  Gasoline
# 3                                       16V MPFI OHV        8.0  Gasoline
# 4                           24V DDI OHV Turbo Diesel        6.0    Diesel
#
#    mileage       transmission       trim          body  doors  \
# 0     10.0  8-Speed Automatic  Series II           SUV    4.0
# 1      1.0  8-Speed Automatic     Laredo           SUV    4.0
# 2      0.0          Automatic     Denali           SUV    4.0
# 3     32.0  8-Speed Automatic    Pursuit           SUV    4.0
# 4     10.0  6-Speed Automatic    Laramie  Pickup Truck    4.0
#
#             exterior_color    interior_color        drivetrain
# 0                    White      Global Black  Four-wheel Drive
# 1                 Metallic      Global Black  Four-wheel Drive
# 2             Summit White  Teak/Light Shale  Four-wheel Drive
# 3  White Knuckle Clearcoat             Black   All-wheel Drive
# 4                   Silver             Black  Four-wheel Drive

# %% [markdown]
# ### `engine` Variable - Missing Values
# - 2 missing values.

# %%
##-- Glance at 2 rows with missing values in the `engine` column --##
vehicle_only_df[vehicle_only_df['engine'].isna()]
# Out:
#                                      name   make        model type  year  \
# 614  2025 Honda CR-V Hybrid Sport Touring  Honda  CR-V Hybrid  New  2025
# 803          2024 Jeep Wagoneer Series II   Jeep     Wagoneer  New  2024
#
#        price engine  cylinders      fuel  mileage                transmission  \
# 614  42150.0    NaN        4.0  Gasoline      1.0  1-Speed CVT with Overdrive
# 803  73999.0    NaN        6.0  Gasoline     59.0           8-Speed Automatic
#
#               trim body  doors          exterior_color interior_color  \
# 614  Sport Touring  SUV    NaN                  Canyon          Black
# 803      Series II  SUV    4.0  Bright White Clearcoat          Black
#
#            drivetrain
# 614   All-wheel Drive
# 803  Four-wheel Drive

# %% [markdown]
# Each row might have similar rows to extract the engine variable from.
# We can inspect further:
# - Model: `CR-V Hybrid`, and
# - Model: `Wagoneer`.

# %%
# Subsetting for model 'CR-V Hybrid'
vehicle_only_df[vehicle_only_df['model'] == 'CR-V Hybrid']
# Out:
#                                      name   make        model type  year  \
# 109  2024 Honda CR-V Hybrid Sport Touring  Honda  CR-V Hybrid  New  2024
# 304          2024 Honda CR-V Hybrid Sport  Honda  CR-V Hybrid  New  2024
# 534        2024 Honda CR-V Hybrid Sport-L  Honda  CR-V Hybrid  New  2024
# 614  2025 Honda CR-V Hybrid Sport Touring  Honda  CR-V Hybrid  New  2025
# 673        2024 Honda CR-V Hybrid Sport-L  Honda  CR-V Hybrid  New  2024
#
#        price               engine  cylinders      fuel  mileage  \
# 109  42005.0  16V GDI DOHC Hybrid        4.0    Hybrid      1.0
# 304  36900.0  16V GDI DOHC Hybrid        4.0    Hybrid      1.0
# 534  40355.0  16V GDI DOHC Hybrid        4.0    Hybrid     68.0
# 614  42150.0                  NaN        4.0  Gasoline      1.0
# 673  37505.0  16V GDI DOHC Hybrid        4.0    Hybrid      0.0
#
#                    transmission           trim body  doors  \
# 109               Automatic CVT  Sport Touring  SUV    4.0
# 304               Automatic CVT          Sport  SUV    4.0
# 534               Automatic CVT        Sport-L  SUV    4.0
# 614  1-Speed CVT with Overdrive  Sport Touring  SUV    NaN
# 673               Automatic CVT        Sport-L  SUV    4.0
#
#             exterior_color interior_color         drivetrain
# 109   Radiant Red Metallic          Black    All-wheel Drive
# 304  Lunar Silver Metallic          Black    All-wheel Drive
# 534   Platinum White Pearl          Black    All-wheel Drive
# 614                 Canyon          Black    All-wheel Drive
# 673   Platinum White Pearl            NaN  Front-wheel Drive

# %%
# Subsetting for model 'Wagoneer'
vehicle_only_df[vehicle_only_df['model'] == 'Wagoneer']
# Out:
#                               name  make     model type  year    price  \
# 0     2024 Jeep Wagoneer Series II  Jeep  Wagoneer  New  2024  74600.0
# 6          2024 Jeep Wagoneer Base  Jeep  Wagoneer  New  2024  63862.0
# 73         2024 Jeep Wagoneer Base  Jeep  Wagoneer  New  2024  63057.0
# 92         2024 Jeep Wagoneer Base  Jeep  Wagoneer  New  2024  60555.0
# 234        2024 Jeep Wagoneer Base  Jeep  Wagoneer  New  2024  65928.0
# 250   2024 Jeep Wagoneer Series II  Jeep  Wagoneer  New  2024  87488.0
# 261   2024 Jeep Wagoneer Series II  Jeep  Wagoneer  New  2024  72908.0
# 399   2024 Jeep Wagoneer Series II  Jeep  Wagoneer  New  2024  75888.0
# 650   2024 Jeep Wagoneer Series II  Jeep  Wagoneer  New  2024  84935.0
# 686        2024 Jeep Wagoneer Base  Jeep  Wagoneer  New  2024  77473.0
# 751  2024 Jeep Wagoneer Series III  Jeep  Wagoneer  New  2024  89595.0
# 772   2024 Jeep Wagoneer Series II  Jeep  Wagoneer  New  2024  79487.0
# 803   2024 Jeep Wagoneer Series II  Jeep  Wagoneer  New  2024  73999.0
# 837        2024 Jeep Wagoneer Base  Jeep  Wagoneer  New  2024  64434.0
# 970   2024 Jeep Wagoneer Series II  Jeep  Wagoneer  New  2024  74625.0
# 999        2024 Jeep Wagoneer Base  Jeep  Wagoneer  New  2024  69085.0
#
#                                  engine  cylinders      fuel  mileage  \
# 0               24V GDI DOHC Twin Turbo        6.0  Gasoline     10.0
# 6               24V GDI DOHC Twin Turbo        6.0  Gasoline      5.0
# 73              24V GDI DOHC Twin Turbo        6.0  Gasoline      NaN
# 92              24V GDI DOHC Twin Turbo        6.0  Gasoline      5.0
# 234             24V GDI DOHC Twin Turbo        6.0  Gasoline      NaN
# 250             24V GDI DOHC Twin Turbo        6.0  Gasoline     22.0
# 261             24V GDI DOHC Twin Turbo        6.0  Gasoline      NaN
# 399             24V GDI DOHC Twin Turbo        6.0  Gasoline      NaN
# 650             24V GDI DOHC Twin Turbo        6.0  Gasoline      1.0
# 686             24V GDI DOHC Twin Turbo        6.0  Gasoline     14.0
# 751             24V GDI DOHC Twin Turbo        6.0  Gasoline      1.0
# 772             24V GDI DOHC Twin Turbo        6.0  Gasoline     18.0
# 803                                 NaN        6.0  Gasoline     59.0
# 837  rbo Regular Unleaded I-6 3.0 L/183        6.0  Gasoline     20.0
# 970             24V GDI DOHC Twin Turbo        6.0  Gasoline     10.0
# 999             24V GDI DOHC Twin Turbo        6.0  Gasoline     20.0
#
#           transmission        trim body  doors  \
# 0    8-Speed Automatic   Series II  SUV    4.0
# 6    8-Speed Automatic        Base  SUV    4.0
# 73   8-Speed Automatic        Base  SUV    4.0
# 92   8-Speed Automatic        Base  SUV    4.0
# 234  8-Speed Automatic        Base  SUV    4.0
# 250  8-Speed Automatic   Series II  SUV    4.0
# 261  8-Speed Automatic   Series II  SUV    4.0
# 399  8-Speed Automatic   Series II  SUV    4.0
# 650  8-Speed Automatic   Series II  SUV    4.0
# 686  8-Speed Automatic        Base  SUV    4.0
# 751  8-Speed Automatic  Series III  SUV    4.0
# 772  8-Speed Automatic   Series II  SUV    4.0
# 803  8-Speed Automatic   Series II  SUV    4.0
# 837          Automatic        Base  SUV    4.0
# 970  8-Speed Automatic   Series II  SUV    4.0
# 999  8-Speed Automatic        Base  SUV    4.0
#
#                       exterior_color interior_color        drivetrain
# 0                              White   Global Black  Four-wheel Drive
# 6             Bright White Clearcoat          Black  Rear-wheel Drive
# 73                          Metallic          Black  Four-wheel Drive
# 92                     Diamond Black          Black  Rear-wheel Drive
# 234           Bright White Clearcoat          Black  Four-wheel Drive
# 250                  Riverrock Green   Global Black  Four-wheel Drive
# 261                    Diamond Black          Black  Four-wheel Drive
# 399                  Riverrock Green          Black  Four-wheel Drive
# 650             Velvet Red Pearlcoat   Global Black  Four-wheel Drive
# 686                    Silver Zynith   Global Black  Four-wheel Drive
# 751           Bright White Clearcoat   Global Black  Four-wheel Drive
# 772                  Riverrock Green          Black  Four-wheel Drive
# 803           Bright White Clearcoat          Black  Four-wheel Drive
# 837  Diamond Black Crystal Pearlcoat          Black  Four-wheel Drive
# 970                           Silver   Global Black  Four-wheel Drive
# 999                    Diamond Black          Black  Four-wheel Drive

# %% [markdown]
# #### Impute using the forward fill method.
# Upon quick inspection, sorting the DataFrame by `model` and `engine` will allow the use of the forward fill method to fill in missing values.

# %%
##-- Sort and ffill --##
vehicle_only_df.sort_values(['model', 'engine'], ascending=False, inplace=True)
vehicle_only_df['engine'].fillna(method='ffill', inplace=True)

print(f"Total Missing Values in 'engine' column: {vehicle_only_df['engine'].isna().sum()}")
print(vehicle_only_df[vehicle_only_df['model'] == 'CR-V Hybrid'][['model', 'engine']])
print(vehicle_only_df[vehicle_only_df['model'] == 'Wagoneer'][['model', 'engine']])
# Out:
# Total Missing Values in 'engine' column: 0
#            model               engine
# 109  CR-V Hybrid  16V GDI DOHC Hybrid
# 304  CR-V Hybrid  16V GDI DOHC Hybrid
# 534  CR-V Hybrid  16V GDI DOHC Hybrid
# 673  CR-V Hybrid  16V GDI DOHC Hybrid
# 614  CR-V Hybrid  16V GDI DOHC Hybrid
#         model                              engine
# 837  Wagoneer  rbo Regular Unleaded I-6 3.0 L/183
# 0    Wagoneer             24V GDI DOHC Twin Turbo
# 6    Wagoneer             24V GDI DOHC Twin Turbo
# 73   Wagoneer             24V GDI DOHC Twin Turbo
# 92   Wagoneer             24V GDI DOHC Twin Turbo
# 234  Wagoneer             24V GDI DOHC Twin Turbo
# 250  Wagoneer             24V GDI DOHC Twin Turbo
# 261  Wagoneer             24V GDI DOHC Twin Turbo
# 399  Wagoneer             24V GDI DOHC Twin Turbo
# 650  Wagoneer             24V GDI DOHC Twin Turbo
# 686  Wagoneer             24V GDI DOHC Twin Turbo
# 751  Wagoneer             24V GDI DOHC Twin Turbo
# 772  Wagoneer             24V GDI DOHC Twin Turbo
# 970  Wagoneer             24V GDI DOHC Twin Turbo
# 999  Wagoneer             24V GDI DOHC Twin Turbo
# 803  Wagoneer             24V GDI DOHC Twin Turbo

# %% [markdown]
# ### `cylinders` variable - Missing Values
# - 103 missing values

# %%
print(f"Total Missing Values in `cylinders` column: {vehicle_only_df['cylinders'].isna().sum()}")

##- Inspect rows where Cylinders has a missing value --##
vehicle_only_df[vehicle_only_df['cylinders'].isna()]
# Out:
# Total Missing Values in `cylinders` column: 103
#                                  name           make      model type  year  \
# 293              2024 BMW i7 eDrive50            BMW         i7  New  2024
# 884                   2024 BMW i7 M70            BMW         i7  New  2024
# 227                   2024 BMW i5 M60            BMW         i5  New  2024
# 419                   2024 BMW i5 M60            BMW         i5  New  2024
# 424                   2024 BMW i5 M60            BMW         i5  New  2024
# ..                                ...            ...        ...  ...   ...
# 121  2024 Mercedes-Benz EQE 350+ Base  Mercedes-Benz   EQE 350+  New  2024
# 893              2025 Honda CR-V EX-L          Honda       CR-V  New  2025
# 14       2024 Chevrolet Blazer EV 2LT      Chevrolet  Blazer EV  New  2024
# 28       2024 Chevrolet Blazer EV 2LT      Chevrolet  Blazer EV  New  2024
# 252       2024 Chevrolet Blazer EV RS      Chevrolet  Blazer EV  New  2024
#
#         price                                             engine  cylinders  \
# 293  110445.0                                                  c        NaN
# 884  195895.0                                                  c        NaN
# 227   91825.0                                                  c        NaN
# 419   96895.0                                                  c        NaN
# 424   93335.0                                                  c        NaN
# ..        ...                                                ...        ...
# 121   79765.0                                                  c        NaN
# 893   38305.0  d>\n\n    \n    <dt>VIN</dt>\n     7FARS4H71SE...        NaN
# 14    51695.0                                                  c        NaN
# 28    52190.0                                                  c        NaN
# 252   55090.0                                                  c        NaN
#
#          fuel  mileage       transmission      trim   body  doors  \
# 293  Electric      5.0  1-Speed Automatic  eDrive50  Sedan    4.0
# 884  Electric      0.0  1-Speed Automatic       M70  Sedan    4.0
# 227  Electric      7.0  1-Speed Automatic       M60  Sedan    4.0
# 419  Electric     37.0  1-Speed Automatic       M60  Sedan    4.0
# 424  Electric      3.0  1-Speed Automatic       M60  Sedan    4.0
# ..        ...      ...                ...       ...    ...    ...
# 121  Electric      9.0  1-Speed Automatic      Base  Sedan    4.0
# 893  Gasoline      0.0      Automatic CVT      EX-L    SUV    NaN
# 14   Electric      4.0  1-Speed Automatic       2LT    SUV    4.0
# 28   Electric      6.0  1-Speed Automatic       2LT    SUV    4.0
# 252  Electric      9.0  1-Speed Automatic        RS    SUV    4.0
#
#               exterior_color interior_color        drivetrain
# 293  Black Sapphire Metallic          Black  Rear-wheel Drive
# 884            Gray Metallic        Caramel   All-wheel Drive
# 227            Mineral White          Black   All-wheel Drive
# 419           Black Sapphire          Black   All-wheel Drive
# 424           Black Sapphire          Black   All-wheel Drive
# ..                       ...            ...               ...
# 121   Twilight Blue Metallic           Gray  Rear-wheel Drive
# 893         Urban Gray Pearl          Black   All-wheel Drive
# 14    Sterling Gray Metallic          Black   All-wheel Drive
# 28               Radiant Red          Black   All-wheel Drive
# 252              Radiant Red          Black   All-wheel Drive
#
# [103 rows x 17 columns]

# %% [markdown]
# - At first glance, vehicles that are EVs, where the fuel variable equals `Electric`, show to have missing values in the cylinders variable.
# - There seems to be more missing values where fuel is different than `Electric`.

# %%
##-- Subset rows based on missing values in the cylinder column, but fuel is not `Electric` Value. --##
vehicle_only_df[(vehicle_only_df['cylinders'].isna()) & (vehicle_only_df['fuel'] != 'Electric')]
# Out:
#                                        name       make       model type  year  \
# 128            2024 Subaru Solterra Premium     Subaru    Solterra  New  2024
# 219             2024 Honda Prologue TOURING      Honda    Prologue  New  2024
# 315             2024 Honda Prologue TOURING      Honda    Prologue  New  2024
# 489             2024 Honda Prologue TOURING      Honda    Prologue  New  2024
# 490             2024 Honda Prologue TOURING      Honda    Prologue  New  2024
# 726  2024 Jaguar I-PACE EV400 R-Dynamic HSE     Jaguar      I-PACE  New  2024
# 610            2024 Chevrolet Equinox EV RS  Chevrolet  Equinox EV  New  2024
# 893                    2025 Honda CR-V EX-L      Honda        CR-V  New  2025
#
#        price                                             engine  cylinders  \
# 128  39934.0                                                  c        NaN
# 219  55800.0                                                  c        NaN
# 315  56550.0                                                  c        NaN
# 489  55800.0                                                  c        NaN
# 490  55800.0                                                  c        NaN
# 726  77053.0  d>\n\n    \n    <dt>VIN</dt>\n     SADHM2S12R1...        NaN
# 610  47495.0               <dt>VIN</dt>\n     3GN7DNRPXRS232327        NaN
# 893  38305.0  d>\n\n    \n    <dt>VIN</dt>\n     7FARS4H71SE...        NaN
#
#          fuel  mileage       transmission                 trim body  doors  \
# 128       NaN      5.0  1-Speed Automatic              Premium  SUV    4.0
# 219       NaN      NaN  1-Speed Automatic              TOURING  SUV    4.0
# 315       NaN      1.0  1-Speed Automatic              TOURING  SUV    4.0
# 489       NaN      NaN  1-Speed Automatic              TOURING  SUV    4.0
# 490       NaN      NaN  1-Speed Automatic              TOURING  SUV    4.0
# 726       NaN      8.0          Automatic  EV400 R-Dynamic HSE  SUV    5.0
# 610       NaN      0.0          Automatic                   RS  SUV    NaN
# 893  Gasoline      0.0      Automatic CVT                 EX-L  SUV    NaN
#
#              exterior_color interior_color         drivetrain
# 128                Galactic          Black    All-wheel Drive
# 219                      BX           Gray    All-wheel Drive
# 315                    Gray          Black    All-wheel Drive
# 489                   Pearl          Black    All-wheel Drive
# 490                    Gray          Black    All-wheel Drive
# 726         Santorini Black          Ebony    All-wheel Drive
# 610  Sterling Gray Metallic          Black  Front-wheel Drive
# 893        Urban Gray Pearl          Black    All-wheel Drive

# %%
##-- Subset for rows on defined model names --##
vehicle_only_df[vehicle_only_df['model'].isin([
    'Solterra', 'Prologue', 'I-PACE', 'Equinox EV', 'CR-V'
])][['make', 'model', 'cylinders', 'fuel']].sort_values('make')
# Out:
#           make       model  cylinders      fuel
# 610  Chevrolet  Equinox EV        NaN       NaN
# 219      Honda    Prologue        NaN       NaN
# 315      Honda    Prologue        NaN       NaN
# 489      Honda    Prologue        NaN       NaN
# 490      Honda    Prologue        NaN       NaN
# 257      Honda        CR-V        4.0    Hybrid
# 893      Honda        CR-V        NaN  Gasoline
# 950      Honda        CR-V        4.0  Gasoline
# 726     Jaguar      I-PACE        NaN       NaN
# 128     Subaru    Solterra        NaN       NaN

# %% [markdown]
# - Judging by the model name, the Chevrolet Equinox EV is an Electric Fuel type.
# - From the Honda website, the Honda Prologue is also an EV.
# - Comparing the next similar row, the missing value for the Honda CR-V is the `4.0` cylinder, and the fuel is `Gasoline`.
# - The Jaguar I-PACE is an EV.
# - and the Subaru Solterra Premium is an EV.
#
# #### Impute the cylinder column and some fuel columns.
# 1. Impute rows with a missing value in the cylinders column and a discrepancy in the fuel column.
# 2. Afterward, use the `.fillna()` function to fill the rest of the columns with the value of `0.0` to represent EVs.

# %%
##-- Fill missing value for CR-V
vehicle_only_df.loc[893, 'cylinders'] = 4.0

##-- Define rows that are supposed to be electric vehicles --##
rows = [
    128, 219, 315, 489, 490, 610, 726
]
for i in rows:
    vehicle_only_df.loc[i, 'cylinders'] = 0.0
    vehicle_only_df.loc[i, 'fuel'] = 'Electric'

# print rows to inspect
vehicle_only_df[vehicle_only_df['model'].isin([
    'Solterra', 'Prologue', 'I-PACE', 'Equinox EV', 'CR-V'
])][['make', 'model', 'cylinders', 'fuel']].sort_values('make')
# Out:
#           make       model  cylinders      fuel
# 610  Chevrolet  Equinox EV        0.0  Electric
# 219      Honda    Prologue        0.0  Electric
# 315      Honda    Prologue        0.0  Electric
# 489      Honda    Prologue        0.0  Electric
# 490      Honda    Prologue        0.0  Electric
# 257      Honda        CR-V        4.0    Hybrid
# 893      Honda        CR-V        4.0  Gasoline
# 950      Honda        CR-V        4.0  Gasoline
# 726     Jaguar      I-PACE        0.0  Electric
# 128     Subaru    Solterra        0.0  Electric

# %%
##-- Fill remaining missing values in cylinders columns with 0.0 for EVs --##
vehicle_only_df['cylinders'].fillna(0.0, inplace=True)

print(f"Total Missing in `cylinders` Column: {vehicle_only_df['cylinders'].isna().sum()}")
# Out:
# Total Missing in `cylinders` Column: 0

# %% [markdown]
# ### `fuel` variable - Missing Values
# - All 7 missing values were imputed from handling the `cylinders` column.

# %%
##-- Count missing values in column. --##
print(f"Total Missing Values in `fuel` Column: {vehicle_only_df['fuel'].isna().sum()}")
# Out:
# Total Missing Values in `fuel` Column: 0

# %% [markdown]
# ### `mileage` variable - Missing Values

# %%
##-- Missing value count in mileage variable --##
print(f"Total Missing Values in `mileage` Column: {vehicle_only_df['mileage'].isna().sum()}")

## Print summary statistics of mileage column.
print(vehicle_only_df['mileage'].describe())
## subset for rows with missing values in mileage column
vehicle_only_df[vehicle_only_df['mileage'].isna()].head(10)
# Out:
# Total Missing Values in `mileage` Column: 32
# count     937.000000
# mean       70.919957
# std       515.657353
# min         0.000000
# 25%         4.000000
# 50%         8.000000
# 75%        13.000000
# max      9711.000000
# Name: mileage, dtype: float64
#                                            name        make          model  \
# 217                2024 Jeep Wrangler 4xe Sport        Jeep   Wrangler 4xe
# 594                2024 Jeep Wrangler 4xe Sport        Jeep   Wrangler 4xe
# 596               2023 Jeep Wrangler 4xe Sahara        Jeep   Wrangler 4xe
# 607              2024 Jeep Wagoneer L Series II        Jeep     Wagoneer L
# 73                      2024 Jeep Wagoneer Base        Jeep       Wagoneer
# 234                     2024 Jeep Wagoneer Base        Jeep       Wagoneer
# 261                2024 Jeep Wagoneer Series II        Jeep       Wagoneer
# 399                2024 Jeep Wagoneer Series II        Jeep       Wagoneer
# 885  2024 Hyundai Tucson Hybrid SEL Convenience     Hyundai  Tucson Hybrid
# 225                 2024 Volkswagen Taos 1.5T S  Volkswagen           Taos
#
#     type  year    price                     engine  cylinders      fuel  \
# 217  New  2024  50755.0  16V GDI DOHC Turbo Hybrid        4.0    Hybrid
# 594  New  2024  51350.0  16V GDI DOHC Turbo Hybrid        4.0    Hybrid
# 596  New  2023  63715.0  16V GDI DOHC Turbo Hybrid        4.0    Hybrid
# 607  New  2024  83845.0    24V GDI DOHC Twin Turbo        6.0  Gasoline
# 73   New  2024  63057.0    24V GDI DOHC Twin Turbo        6.0  Gasoline
# 234  New  2024  65928.0    24V GDI DOHC Twin Turbo        6.0  Gasoline
# 261  New  2024  72908.0    24V GDI DOHC Twin Turbo        6.0  Gasoline
# 399  New  2024  75888.0    24V GDI DOHC Twin Turbo        6.0  Gasoline
# 885  New  2024  37215.0  16V GDI DOHC Turbo Hybrid        4.0    Hybrid
# 225  New  2024  25895.0         16V GDI DOHC Turbo        4.0  Gasoline
#
#      mileage                    transmission             trim body  doors  \
# 217      NaN               8-Speed Automatic            Sport  SUV    4.0
# 594      NaN               8-Speed Automatic            Sport  SUV    4.0
# 596      NaN               8-Speed Automatic           Sahara  SUV    4.0
# 607      NaN               8-Speed Automatic        Series II  SUV    4.0
# 73       NaN               8-Speed Automatic             Base  SUV    4.0
# 234      NaN               8-Speed Automatic             Base  SUV    4.0
# 261      NaN               8-Speed Automatic        Series II  SUV    4.0
# 399      NaN               8-Speed Automatic        Series II  SUV    4.0
# 885      NaN               6-Speed Automatic  SEL Convenience  SUV    4.0
# 225      NaN  7-Speed DSGA? Automatic w/ 4MO           1.5T S  SUV    4.0
#
#               exterior_color interior_color        drivetrain
# 217   Bright White Clearcoat          Black  Four-wheel Drive
# 594          Anvil Clearcoat          Black  Four-wheel Drive
# 596  Silver Zynith Clearcoat          Black  Four-wheel Drive
# 607   Bright White Clearcoat          Black  Four-wheel Drive
# 73                  Metallic          Black  Four-wheel Drive
# 234   Bright White Clearcoat          Black  Four-wheel Drive
# 261            Diamond Black          Black  Four-wheel Drive
# 399          Riverrock Green          Black  Four-wheel Drive
# 885              Black Pearl           Gray   All-wheel Drive
# 225  Deep Black Pearl Effect          Black   All-wheel Drive

# %% [markdown]
# - Judging by how new these vehicles are, the assumption can be made that the total mileage on these vehicles would be low.
# - Inspecting the mean (mean = `70.92`) and the median (median = `8.0`) of the mileage variable, the distribution is right-skewed.
# - With the right-skewed distribution and the fact that these are new vehicles, it makes sense to use the median to impute these missing values.
#
# #### Impute the `mileage` variable using the median.
# - The median is `8.0` for the mileage column.

# %%
##-- Fill missing value with median value --##
vehicle_only_df['mileage'].fillna(8.0, inplace=True)

##-- Missing value count in mileage variable --##
print(f"Total Missing Values in `mileage` Column: {vehicle_only_df['mileage'].isna().sum()}")
# Out:
# Total Missing Values in `mileage` Column: 0

# %% [markdown]
# ### `transmission` variable - Missing Values
# - 2 missing values

# %%
##-- Count missing values in the `transmission` column --##
print(f"Total Missing Values in `transmission` Column: {vehicle_only_df['transmission'].isna().sum()}")

# Visually inspect rows with the missing value
vehicle_only_df[vehicle_only_df['transmission'].isna()]
# Out:
# Total Missing Values in `transmission` Column: 2
#                                                name           make  \
# 940  2024 Ford Transit-350 148 WB Medium Roof Cargo           Ford
# 725          2024 Mercedes-Benz EQS 450 Base 4MATIC  Mercedes-Benz
#
#            model type  year     price                      engine  cylinders  \
# 940  Transit-350  New  2024   52530.0  24V PDI DOHC Flexible Fuel        6.0
# 725      EQS 450  New  2024  111245.0                           c        0.0
#
#               fuel  mileage transmission                      trim       body  \
# 940  E85 Flex Fuel      1.0          NaN  148 WB Medium Roof Cargo  Cargo Van
# 725       Electric     10.0          NaN               Base 4MATIC      Sedan
#
#      doors exterior_color interior_color        drivetrain
# 940    3.0          White            NaN  Rear-wheel Drive
# 725    4.0          White          Black   All-wheel Drive

# %%
##-- Subset rows by defined model name --##
vehicle_only_df[vehicle_only_df['model'].isin(['Transit-350', 'EQS 450'])]
# Out:
#                                                name           make  \
# 897                      2024 Ford Transit-350 Base           Ford
# 940  2024 Ford Transit-350 148 WB Medium Roof Cargo           Ford
# 793                      2023 Ford Transit-350 Base           Ford
# 805                          2023 Ford Transit-350            Ford
# 142          2024 Mercedes-Benz EQS 450 Base 4MATIC  Mercedes-Benz
# 146          2024 Mercedes-Benz EQS 450 Base 4MATIC  Mercedes-Benz
# 253          2024 Mercedes-Benz EQS 450 Base 4MATIC  Mercedes-Benz
# 328          2024 Mercedes-Benz EQS 450 Base 4MATIC  Mercedes-Benz
# 372          2024 Mercedes-Benz EQS 450 Base 4MATIC  Mercedes-Benz
# 373          2024 Mercedes-Benz EQS 450 Base 4MATIC  Mercedes-Benz
# 413          2024 Mercedes-Benz EQS 450 Base 4MATIC  Mercedes-Benz
# 484          2024 Mercedes-Benz EQS 450 Base 4MATIC  Mercedes-Benz
# 725          2024 Mercedes-Benz EQS 450 Base 4MATIC  Mercedes-Benz
#
#            model type  year     price  \
# 897  Transit-350  New  2024   74391.0
# 940  Transit-350  New  2024   52530.0
# 793  Transit-350  New  2023   57000.0
# 805  Transit-350  New  2023   54525.0
# 142      EQS 450  New  2024  112702.5
# 146      EQS 450  New  2024  109545.0
# 253      EQS 450  New  2024  110395.0
# 328      EQS 450  New  2024  112702.5
# 372      EQS 450  New  2024  112702.5
# 373      EQS 450  New  2024  114850.0
# 413      EQS 450  New  2024  114160.0
# 484      EQS 450  New  2024  117985.0
# 725      EQS 450  New  2024  111245.0
#
#                                                 engine  cylinders  \
# 897  6 port/direct injection, DOHC, variable valve ...        6.0
# 940                         24V PDI DOHC Flexible Fuel        6.0
# 793                            24V GDI DOHC Twin Turbo        6.0
# 805                            24V GDI DOHC Twin Turbo        6.0
# 142                                                  c        0.0
# 146                                                  c        0.0
# 253                                                  c        0.0
# 328                                                  c        0.0
# 372                                                  c        0.0
# 373                                                  c        0.0
# 413                                                  c        0.0
# 484                                                  c        0.0
# 725                                                  c        0.0
#
#               fuel  mileage        transmission                      trim  \
# 897       Gasoline     85.0           Automatic                      Base
# 940  E85 Flex Fuel      1.0                 NaN  148 WB Medium Roof Cargo
# 793       Gasoline   5581.0  10-Speed Automatic                      Base
# 805       Gasoline      0.0  10-Speed Automatic                       NaN
# 142       Electric      8.0           Automatic               Base 4MATIC
# 146       Electric     10.0   1-Speed Automatic               Base 4MATIC
# 253       Electric      5.0           Automatic               Base 4MATIC
# 328       Electric     10.0           Automatic               Base 4MATIC
# 372       Electric      4.0           Automatic               Base 4MATIC
# 373       Electric      8.0   1-Speed Automatic               Base 4MATIC
# 413       Electric      5.0   1-Speed Automatic               Base 4MATIC
# 484       Electric      1.0           Automatic               Base 4MATIC
# 725       Electric     10.0                 NaN               Base 4MATIC
#
#           body  doors           exterior_color     interior_color  \
# 897  Cargo Van    3.0             Oxford White               gray
# 940  Cargo Van    3.0                    White                NaN
# 793  Cargo Van    3.0                    White               Gray
# 805  Cargo Van    3.0             Oxford White  Dark Palazzo Gray
# 142      Sedan    4.0   Graphite Gray Metallic               Gray
# 146        SUV    4.0                    Black              Black
# 253      Sedan    4.0  Obsidian Black Metallic              Black
# 328      Sedan    4.0  Obsidian Black Metallic              Black
# 372      Sedan    4.0              Polar White    Macchiato Beige
# 373        SUV    4.0                      NaN              Black
# 413        SUV    4.0              Alpine Gray              Black
# 484      Sedan    4.0  Obsidian Black Metallic              Black
# 725      Sedan    4.0                    White              Black
#
#            drivetrain
# 897   All-wheel Drive
# 940  Rear-wheel Drive
# 793  Rear-wheel Drive
# 805  Rear-wheel Drive
# 142   All-wheel Drive
# 146   All-wheel Drive
# 253   All-wheel Drive
# 328   All-wheel Drive
# 372   All-wheel Drive
# 373   All-wheel Drive
# 413   All-wheel Drive
# 484   All-wheel Drive
# 725   All-wheel Drive

# %% [markdown]
# - Similar vehicle models look like they are Automatic Transmission
#
# #### Impute the `transmission` variable by filling in.
# - Using `.fillna()` the missing values will be imputed with the string value of `'Automatic'`

# %%
# Impute using .fillna()
vehicle_only_df['transmission'].fillna('Automatic', inplace=True)

##-- Count missing values in the `transmission` column --##
print(f"Total Missing Values in `transmission` Column: {vehicle_only_df['transmission'].isna().sum()}")
# Out:
# Total Missing Values in `transmission` Column: 0

# %% [markdown]
# ## Detection of Outliers

# %%
# Create functions
def outlier_counter(df, col):  # Counts rows that are determined to be outliers
    lower_quart = np.quantile(df[col], 0.25)
    upper_quart = np.quantile(df[col], 0.75)
    iqr = upper_quart - lower_quart
    lower_threshold = lower_quart - 1.5 * iqr
    upper_threshold = upper_quart + 1.5 * iqr
    outliers = df[(df[col] < lower_threshold) | (df[col] > upper_threshold)]
    return(f'---------- \n Total outliers from {col}: {outliers.shape[0]} \n Percentage of data: {(outliers.shape[0]/df.shape[0])*100}% \n')

def quantitative_visualizer(df, variable):  # Function that visualizes Boxplot and Histogram
    
    median = np.median(df[variable])
    mean = np.mean(df[variable])
    
    fig, ax = plt.subplots(figsize=(10, 3))
    
    ax.hist(df[variable], bins=10)
    ax.set_xlabel(outlier_counter(df, variable))
    
    ax2 = ax.twinx()
    ax2.boxplot(df[variable], vert=False)
    ax2.annotate(f'Median: {median}', xy=(median, 1.10))
    ax2.annotate(f'  Mean: {mean}', xy=(mean, 0.75), color='darkgreen')
    ax2.axvline(x=mean, color='darkgreen', linestyle='--', alpha=0.5)

    ax.set_title(f'Outlier Detection on {variable} Column')
    plt.show()
